# %%
# NUTS test

# %%
from addit.dit import rundit
import jax.numpy as jnp
import numpy as np
from addit.ncf import inc3D

# %%
np.random.seed(0)

# %%
N=10000
Ng_nu=20000
Ng_beta=10
Ng_gammaL=10

nus=np.linspace(2050.0,2250.0,Ng_nu) #nu grid
beta_grid=np.logspace(-2,4,Ng_beta) #beta grid
gammaL_grid=np.logspace(-2,4,Ng_gammaL)#gammaL grid
S=np.logspace(0.0,2.0,N)
S[0:10]=1000.0

# %%
nu_lines=np.random.rand(N)*(nus[-1]-nus[0]-50.0)+nus[0]+25.0
beta=np.random.rand(N)*1.0
gammaL=np.random.rand(N)*1.0

# %%
F0in=rundit(S,nu_lines,beta,gammaL,nus,beta_grid,gammaL_grid)

# %%
F0obs=F0in+np.random.normal(size=len(nus))*np.median(F0in)*0.05 #5%

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(nus,F0in,color="C1",label="in")
plt.plot(nus,F0obs,alpha=0.3,lw=0.3,color="C1",label="w/ noise")
plt.legend()
plt.show()

# %%
import arviz
import numpyro.distributions as dist
import numpyro
from numpyro.infer import MCMC, NUTS
from numpyro.infer import Predictive
from numpyro.diagnostics import hpdi

# %%
def model_c(nu,y):
    sigma = numpyro.sample('sigma', dist.Exponential(np.median(F0in)*0.05))
    T = numpyro.sample('T', dist.Exponential(1.0))
    mu=rundit(S,nu_lines,beta*jnp.sqrt(T),gammaL,nus,beta_grid,gammaL_grid)
    numpyro.sample('y', dist.Normal(mu, sigma), obs=y)

# %%
from jax import random
rng_key = random.PRNGKey(0)
rng_key, rng_key_ = random.split(rng_key)
num_warmup, num_samples = 100, 200

# %%
kernel = NUTS(model_c,forward_mode_differentiation=True)
mcmc = MCMC(kernel, num_warmup, num_samples)
mcmc.run(rng_key_, nu=nus, y=F0obs)
# Out:
# sample: 100%|██████████| 300/300 [56:07<00:00,  9.85s/it, 3 steps of size 1.15e-01. acc. prob=0.95]

# %%
posterior_sample = mcmc.get_samples()
pred = Predictive(model_c,posterior_sample)
predictions = pred(rng_key_,nu=nus,y=None)
                                                                                    
median_mu = jnp.median(predictions["y"],axis=0)
hpdi_mu = hpdi(predictions["y"], 0.9)

# %%
fig=plt.figure()
ax=fig.add_subplot(211)                                                 
ax.plot(nus,median_mu,color="C0")

ax.fill_between(nus, hpdi_mu[0], hpdi_mu[1], alpha=0.3, interpolate=True,color="C0",
                label="90% area")
ax=fig.add_subplot(212) 
ax.plot(nus,F0obs,color="C1",label="data",alpha=0.3)
plt.xlabel("$\\nu$",fontsize=16)

plt.legend()

# %%
#reverse
kernel = NUTS(model_c)
mcmc = MCMC(kernel, num_warmup, num_samples)
mcmc.run(rng_key_, nu=nus, y=F0obs)
# Out:
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-13-359f4e15398a> in <module>
#       3 mcmc = MCMC(kernel, num_warmup, num_samples)
# ----> 4 mcmc.run(rng_key_, nu=nus, y=F0obs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/mcmc.py in run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     559         if self.num_chains == 1:
# --> 560             states_flat, last_state = partial_map_fn(map_args)
#     561             states = tree_map(lambda x: x[jnp.newaxis, ...], states_flat)
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/mcmc.py in _single_chain_mcmc(self, init, args, kwargs, collect_fields)
#     353                 model_args=args,
# --> 354                 model_kwargs=kwargs,
#     355             )
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/hmc.py in init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     689         init_params = self._init_state(
# --> 690             rng_key_init_model, model_args, model_kwargs, init_params
#     691         )
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/hmc.py in _init_state(self, rng_key, model_args, model_kwargs, init_params)
#     641                 model_kwargs=model_kwargs,
# --> 642                 forward_mode_differentiation=self._forward_mode_differentiation,
#     643             )
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     565         forward_mode_differentiation=forward_mode_differentiation,
# --> 566         validate_grad=validate_grad,
#     567     )
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in find_valid_initial_params(rng_key, model, init_strategy, enum, model_args, model_kwargs, prototype_params, forward_mode_differentiation, validate_grad)
#     307         (init_params, pe, z_grad), is_valid = _find_valid_params(
# --> 308             rng_key, exit_early=True
#     309         )
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in _find_valid_params(rng_key, exit_early)
#     292             # where we can avoid compiling body_fn in while_loop.
# --> 293             _, _, (init_params, pe, z_grad), is_valid = init_state = body_fn(init_state)
#     294             if not_jax_tracer(is_valid):
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in body_fn(state)
#     277             else:
# --> 278                 pe, z_grad = value_and_grad(potential_fn)(params)
#     279             z_grad_flat = ravel_pytree(z_grad)[0]
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in potential_energy(model, model_args, model_kwargs, params, enum)
#     171     log_joint, model_trace = log_density_(
# --> 172         substituted_model, model_args, model_kwargs, {}
#     173     )
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in log_density(model, model_args, model_kwargs, params)
#      50     model = substitute(model, data=params)
# ---> 51     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#      52     log_joint = jnp.zeros(())
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     164         """
# --> 165         self(*args, **kwargs)
#     166         return self.trace
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#
# <ipython-input-11-86641adfbded> in model_c(nu, y)
#       3     T = numpyro.sample('T', dist.Exponential(1.0))
# ----> 4     mu=rundit(S,nu_lines,beta*jnp.sqrt(T),gammaL,nus,beta_grid,gammaL_grid)
#       5     numpyro.sample('y', dist.Normal(mu, sigma), obs=y)
#
# FilteredStackTrace: RuntimeError: Resource exhausted: Out of memory while trying to allocate 8000000000 bytes.: while running replica 0 and partition 0 of a replicated computation (other replicas may have failed as well).
#
# The stack trace above excludes JAX-internal frames.
# The following is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-359f4e15398a> in <module>
#       2 kernel = NUTS(model_c)
#       3 mcmc = MCMC(kernel, num_warmup, num_samples)
# ----> 4 mcmc.run(rng_key_, nu=nus, y=F0obs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/mcmc.py in run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     558         map_args = (rng_key, init_state, init_params)
#     559         if self.num_chains == 1:
# --> 560             states_flat, last_state = partial_map_fn(map_args)
#     561             states = tree_map(lambda x: x[jnp.newaxis, ...], states_flat)
#     562         else:
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/mcmc.py in _single_chain_mcmc(self, init, args, kwargs, collect_fields)
#     352                 init_params,
#     353                 model_args=args,
# --> 354                 model_kwargs=kwargs,
#     355             )
#     356         sample_fn, postprocess_fn = self._get_cached_fns()
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/hmc.py in init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     688             )
#     689         init_params = self._init_state(
# --> 690             rng_key_init_model, model_args, model_kwargs, init_params
#     691         )
#     692         if self._potential_fn and init_params is None:
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/hmc.py in _init_state(self, rng_key, model_args, model_kwargs, init_params)
#     640                 model_args=model_args,
#     641                 model_kwargs=model_kwargs,
# --> 642                 forward_mode_differentiation=self._forward_mode_differentiation,
#     643             )
#     644             if self._init_fn is None:
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     564         prototype_params=prototype_params,
#     565         forward_mode_differentiation=forward_mode_differentiation,
# --> 566         validate_grad=validate_grad,
#     567     )
#     568
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in find_valid_initial_params(rng_key, model, init_strategy, enum, model_args, model_kwargs, prototype_params, forward_mode_differentiation, validate_grad)
#     306     if rng_key.ndim == 1:
#     307         (init_params, pe, z_grad), is_valid = _find_valid_params(
# --> 308             rng_key, exit_early=True
#     309         )
#     310     else:
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in _find_valid_params(rng_key, exit_early)
#     291             # Early return if valid params found. This is only helpful for single chain,
#     292             # where we can avoid compiling body_fn in while_loop.
# --> 293             _, _, (init_params, pe, z_grad), is_valid = init_state = body_fn(init_state)
#     294             if not_jax_tracer(is_valid):
#     295                 if device_get(is_valid):
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in body_fn(state)
#     276                 z_grad = jacfwd(potential_fn)(params)
#     277             else:
# --> 278                 pe, z_grad = value_and_grad(potential_fn)(params)
#     279             z_grad_flat = ravel_pytree(z_grad)[0]
#     280             is_valid = jnp.isfinite(pe) & jnp.all(jnp.isfinite(z_grad_flat))
#
# ~/anaconda3/lib/python3.7/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     803     tree_map(partial(_check_input_dtype_grad, holomorphic, allow_int), dyn_args)
#     804     if not has_aux:
# --> 805       ans, vjp_py = _vjp(f_partial, *dyn_args)
#     806     else:
#     807       ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in _vjp(fun, has_aux, *primals)
#    1872   if not has_aux:
#    1873     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1874     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    1875     out_tree = out_tree()
#    1876   else:
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     112 def vjp(traceable, primals, has_aux=False):
#     113   if not has_aux:
# --> 114     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     115   else:
#     116     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      99   _, in_tree = tree_flatten(((primals, primals), {}))
#     100   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 101   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#     102   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     103   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate)
#     504   with core.new_main(JaxprTrace) as main:
#     505     fun = trace_to_subjaxpr(fun, main, instantiate)
# --> 506     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     507     assert not env
#     508     del main
#
# ~/anaconda3/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     158
#     159     try:
# --> 160       ans = self.f(*args, **dict(self.params, **kwargs))
#     161     except:
#     162       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in potential_energy(model, model_args, model_kwargs, params, enum)
#     170     # no param is needed for log_density computation because we already substitute
#     171     log_joint, model_trace = log_density_(
# --> 172         substituted_model, model_args, model_kwargs, {}
#     173     )
#     174     return -log_joint
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/infer/util.py in log_density(model, model_args, model_kwargs, params)
#      49     """
#      50     model = substitute(model, data=params)
# ---> 51     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#      52     log_joint = jnp.zeros(())
#      53     for site in model_trace.values():
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     163         :return: `OrderedDict` containing the execution trace.
#     164         """
# --> 165         self(*args, **kwargs)
#     166         return self.trace
#     167
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      85             return self
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#      89
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      85             return self
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#      89
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      85             return self
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#      89
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      85             return self
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#      89
#
# ~/anaconda3/lib/python3.7/site-packages/numpyro-0.6.0-py3.7.egg/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      85             return self
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#      89
#
# <ipython-input-11-86641adfbded> in model_c(nu, y)
#       2     sigma = numpyro.sample('sigma', dist.Exponential(np.median(F0in)*0.05))
#       3     T = numpyro.sample('T', dist.Exponential(1.0))
# ----> 4     mu=rundit(S,nu_lines,beta*jnp.sqrt(T),gammaL,nus,beta_grid,gammaL_grid)
#       5     numpyro.sample('y', dist.Normal(mu, sigma), obs=y)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     393       return cpp_jitted_f(*args, **kwargs)
#     394     else:
# --> 395       return cpp_jitted_f(context, *args, **kwargs)
#     396   f_jitted._cpp_jitted_f = cpp_jitted_f
#     397
#
# ~/anaconda3/lib/python3.7/site-packages/jax/api.py in cache_miss(_, *args, **kwargs)
#     290         backend=backend,
#     291         name=flat_fun.__name__,
# --> 292         donated_invars=donated_invars)
#     293     out_pytree_def = out_tree()
#     294     out = tree_unflatten(out_pytree_def, out_flat)
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1233
#    1234   def bind(self, fun, *args, **params):
# -> 1235     return call_bind(self, fun, *args, **params)
#    1236
#    1237   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1224   tracers = map(top_trace.full_raise, args)
#    1225   with maybe_new_sublevel(top_trace):
# -> 1226     outs = primitive.process(top_trace, fun, tracers, params)
#    1227   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1228
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1236
#    1237   def process(self, trace, fun, tracers, params):
# -> 1238     return trace.process_call(self, fun, tracers, params)
#    1239
#    1240   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     316     update_params = call_param_updaters.get(call_primitive)
#     317     new_params = update_params(params, nz_tangents) if update_params else params
# --> 318     result = call_primitive.bind(f_jvp, *primals, *nonzero_tangents, **new_params)
#     319     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#     320     return [JVPTracer(self, p, t) for p, t in zip(primal_out, tangent_out)]
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1233
#    1234   def bind(self, fun, *args, **params):
# -> 1235     return call_bind(self, fun, *args, **params)
#    1236
#    1237   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1224   tracers = map(top_trace.full_raise, args)
#    1225   with maybe_new_sublevel(top_trace):
# -> 1226     outs = primitive.process(top_trace, fun, tracers, params)
#    1227   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1228
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1236
#    1237   def process(self, trace, fun, tracers, params):
# -> 1238     return trace.process_call(self, fun, tracers, params)
#    1239
#    1240   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_call(self, primitive, f, tracers, params)
#     191       app = partial(primitive.bind, **params)
#     192     jaxpr, out_pvals, consts, env_tracers = self.partial_eval(
# --> 193         f, in_pvals, app, instantiate=False)
#     194     if primitive.map_primitive:
#     195       unmapped_aval = partial(core.unmapped_aval, params['axis_size'])
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in partial_eval(self, f, pvals, app, instantiate)
#     298     f = trace_to_subjaxpr(f, self.main, instantiate)
#     299     f, aux = partial_eval_wrapper(f, tuple(in_avals))
# --> 300     out_flat, (out_avals, jaxpr, env) = app(f, *in_consts), aux()
#     301     out_consts, consts = split_list(out_flat, [len(out_flat)-len(jaxpr.constvars)])
#     302     out_pvs = map(PartialVal, zip(out_avals, out_consts))
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1233
#    1234   def bind(self, fun, *args, **params):
# -> 1235     return call_bind(self, fun, *args, **params)
#    1236
#    1237   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1224   tracers = map(top_trace.full_raise, args)
#    1225   with maybe_new_sublevel(top_trace):
# -> 1226     outs = primitive.process(top_trace, fun, tracers, params)
#    1227   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1228
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1236
#    1237   def process(self, trace, fun, tracers, params):
# -> 1238     return trace.process_call(self, fun, tracers, params)
#    1239
#    1240   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.7/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     596
#     597   def process_call(self, primitive, f, tracers, params):
# --> 598     return primitive.impl(f, *tracers, **params)
#     599   process_map = process_call
#     600
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     577                                *unsafe_map(arg_spec, args))
#     578   try:
# --> 579     return compiled_fun(*args)
#     580   except FloatingPointError:
#     581     assert FLAGS.jax_debug_nans  # compiled_fun can only raise in this case
#
# ~/anaconda3/lib/python3.7/site-packages/jax/interpreters/xla.py in _execute_compiled(compiled, avals, handlers, *args)
#     835   device, = compiled.local_devices()
#     836   input_bufs = list(it.chain.from_iterable(device_put(x, device) for x in args if x is not token))
# --> 837   out_bufs = compiled.execute(input_bufs)
#     838   if FLAGS.jax_debug_nans: check_nans(xla_call_p, out_bufs)
#     839   return [handler(*bs) for handler, bs in zip(handlers, _partition_outputs(avals, out_bufs))]
#
# RuntimeError: Resource exhausted: Out of memory while trying to allocate 8000000000 bytes.: while running replica 0 and partition 0 of a replicated computation (other replicas may have failed as well).
